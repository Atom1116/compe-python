# %%
import os

# %%
for curDir, dirs, files in os.walk('.'):
    print(files)
# Out:
# ['.DS_Store', 'list.ipynb', 'test_jupyter.ipynb', 'study_python.ipynb', 'class.ipynb', 'README.md', 'dict.ipynb', '.gitignore', 'os_controll.ipynb']
# ['README.md', 'input.py', 'bit_full_research.py']
# ['README.md']
# ['README.md']
# ['.DS_Store', 'pyvenv.cfg']
# ['pip3.7', 'jupyter-run', 'jupyter-nbextension', 'python3', 'easy_install', 'python', 'pip3', 'ipython', 'jupyter-notebook', 'activate.fish', 'easy_install-3.7', 'send2trash', 'register-python-argcomplete', 'ipython3', 'pip', 'jupyter-nbconvert', 'jsonschema', 'python-argcomplete-check-easy-install-script', 'jupyter-troubleshoot', 'pygmentize', 'jupyter-migrate', 'activate', 'jupyter-console', 'python-argcomplete-tcsh', 'jupyter-serverextension', 'iptest3', 'jupyter-trust', 'jupyter-qtconsole', 'jupyter-kernelspec', 'jupyter-kernel', 'jupyter', 'jupyter-bundlerextension', 'iptest', 'activate-global-python-argcomplete', 'activate.csh']
# []
# []
# []
# []
# ['widgetsnbextension.json']
# ['.DS_Store']
# ['.DS_Store']
# ...

# %%
lists = os.listdir('.')
lists.sort()
lists
# Out:
# ['.DS_Store',
#  '.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'README.md',
#  'algorithm',
#  'atcoder',
#  'boot_camp_beginner',
#  'class.ipynb',
#  'dict.ipynb',
#  'list.ipynb',
#  'os_controll.ipynb',
#  'pu37',
#  'study_python.ipynb',
#  'technique',
#  'test_jupyter.ipynb']
