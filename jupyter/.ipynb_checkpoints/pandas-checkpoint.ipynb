# %%
# !pip list | grep pandas
# !pip install pandas
# Out:
# pandas              1.3.2
# ...

# %%
# !pip list | grep pandas
# Out:
# pandas              1.3.2

# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df_as = df.sort_values(by='latitude') # latitudeを昇順でソート
df_as
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 680      -117.04     32.54                 7.0        938.0           297.0
# 796      -117.06     32.55                 5.0       3223.0           940.0
# 995      -117.09     32.55                 8.0       6533.0          1217.0
# 679      -117.04     32.55                15.0       2206.0           648.0
# 1161     -117.12     32.56                20.0       2524.0           682.0
# ...          ...       ...                 ...          ...             ...
# 15516    -122.33     41.86                19.0       3599.0           695.0
# 16833    -123.26     41.86                25.0       2344.0           532.0
# 16883    -123.83     41.88                18.0       1504.0           357.0
# 16497    -122.64     41.95                18.0       1867.0           424.0
# 16939    -124.14     41.95                21.0       2696.0           578.0
#
# ...
